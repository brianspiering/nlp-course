# %% [markdown]
# Train a LSTM to generate words.
# ------
#
# 1. Start running code (it takes a while)
# 2. Read through the code
# 3. Train on your corpus
# 4. Share your favorite new sentence
#
# Suggested corpus:
#
# - Trump's tweets https://data.world/briangriffey/trump-tweets
# - Elon Musk tweets https://data.world/adamhelsinger/elon-musk-tweets-until-4-6-17
#
# Based on [this code](https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py)

# %%
run lstm_text_generation.py
# Out:
# Using TensorFlow backend.
# corpus length: 148,545
# total chars: 47
# nb sequences: 49,502
# Vectorization...
# Build model...
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 49502/49502 [==============================] - 65s 1ms/step - loss: 2.3071
#
# ----- diversity: 0.2
# ----- Generating with seed: "t ma chatte?' which was the first senten"
# t ma chatte?' which was the first sentent and the was she whet whing the was she hat the had the gring the whing the hard the was she whe all the hand the hand and the garders the hand the was gryplong the hand the ding, and the whing and the was a ding the farder the was she whidet of the was a ding the hand the hand the parders the whing and and the hand the was a dren the was grand the was she said the hand the said the hand the hand
#
# ----- diversity: 0.5
# ----- Generating with seed: "t ma chatte?' which was the first senten"
# t ma chatte?' which was the first sententing the darsedones go hard the lither all all anding the said the be whing and and macking, and all the was come,
# and the harder hand and to gar go gherser the the gardent the of thistery mach she gand and the hard the the cand the whowht the waid the cronded, `and she all come in a the a buther was such the gerits the doring ther and the whele she hand the whonss the hand all no han sime of then
#
# ----- diversity: 1.0
# ----- Generating with seed: "t ma chatte?' which was the first senten"
# t ma chatte?' which was the first senten---of `whid's croes!'
#
#
#    a  `of hourdjbotito ablatdgrye to agot, the fory, `no she dorabigh pares and, andaliin.  `wo dand thly me whildevorss seands buthipg'en'
#
# a frould twe homkew
# tifuiss queefthwents boking?'
#
#                     a din hem, whe
# alice, but
# u laid:  `bwhs
# loutntunarakenstwestle, as i whasdlomisurhy mingtowat fald wuy anding
# to hered and praves shengingt co
# way
# loy lich she ca
#
# ----- diversity: 1.2
# ----- Generating with seed: "t ma chatte?' which was the first senten"
# t ma chatte?' which was the first sentensex.
#            but
# erypp iows ulcon ings itfidkae wall?'  the
# blond! whoguon yo whald anon pury hut some orghys qustankse:
# 's as tume!t angersony agalict
# of nathed he rimngofnery t'mmalite  pintsamousn anfinc, and
# ceng be fir?' freme'u-f
#
# lame, us the knouts' aco it!  the quonknly to doulling,          m anders, `wh, shes laking; dores--`quicgs rowwing irvousg way nors!'
# shreaplly no tree was  f
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 49502/49502 [==============================] - 69s 1ms/step - loss: 1.7862
#
# ----- diversity: 0.2
# ----- Generating with seed: " `there's certainly too much pepper in t"
#  `there's certainly too much pepper in the done they here they well her all it was gone the could to the sound the sound the sound the hatter the hatter they said to the hatter the gare of the dore of the gorself, and they said to the said, and they way here the said to the dorean the goor here the could the could to the sain, and they all there they here of the said to the sepenter the sound of the hatter a the mace they here the mouse
#
# ----- diversity: 0.5
# ----- Generating with seed: " `there's certainly too much pepper in t"
#  `there's certainly too much pepper in the march hat ore, and all eare out the
# cone of to the sall done here perped the sound the coulled they was of then seeped they looked alling of the eance.
#
#   `they way it was it ound the queen, it at the
# catled the teuch
# it was  as alice.
#
#   and they was it said again, and be the king of they head of the gand of to all the mach say one was it way hare of the seed fout of there the mame it she had
#
# ----- diversity: 1.0
# ----- Generating with seed: " `there's certainly too much pepper in t"
#  `there's certainly too much pepper in theing bearonted and very hermopt inditahtly?'  aid she ware nr.
# ard were be where dore-bord ssoom it him, if't som, ald thiss.  you know!  it, and th, they his mock titther sein, -alice one monedwod
# it's all totsen't helfed her papad asaks!  they be coulds of beean teoneding oull pibtiok, they leneed well egate berepenttsupios, asuber.
#
#   the cery apontage--  perples here.
# that you for
#
# the drown
#
# ----- diversity: 1.2
# ----- Generating with seed: " `there's certainly too much pepper in t"
#  `there's certainly too much pepper in till up
# this howned tome willed
# of that fapbocly hared-"f
# i myesefoned with ised, ald they sire, twese--a
# 't ay thy herpepler
# ppirsed nut wun saictgan louse:  they hohe wat
# dirrate.
#
#   `that an lough crumner
# all you they well, wich depses, i'
# tas thing fyow sitharuoue ifvullon, however foos!' she in't mishralirnoof, and and ladg the tomp
# i jumears,' cach all off ithait be then armaed
# figoncounds is
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 49502/49502 [==============================] - 84s 2ms/step - loss: 1.6123
#
# ----- diversity: 0.2
# ----- Generating with seed: "nce first--verdict afterwards.'
#
#   `stuf"
# nce first--verdict afterwards.'
#
#   `stufing the grown on the sard on the great on it and she to be a parter at the sadd on a stone of the sadd on a little said to the didn't all a lite of the didn't be the didn't so the great on all a peared to the didn't all the sand of the grown in a looked at the was a little said to the didn't in the didn't the said to a little seem the was a persed to see the didn't it was out on the didner the sar
#
# ----- diversity: 0.5
# ----- Generating with seed: "nce first--verdict afterwards.'
#
#   `stuf"
# nce first--verdict afterwards.'
#
#   `stuft had she tell the diden a pit once.
#
#   `i shat the sead of the didner.
#
#   `the whit alle thing to see wonding once to the did the with the was a be the rabbit
# of the greater.
#
#   `what she said again again
# of the grown in at a great all alice be ond and wand to the did the grind of the sure the didner alice.
#
#   `ore the was a dine, and she the range of the dident the grown and ame de of the thied
#
# ----- diversity: 1.0
# ----- Generating with seed: "nce first--verdict afterwards.'
#
#   `stuf"
# nce first--verdict afterwards.'
#
#   `stufing ally ilbo
# hyesunt; `why, ehe inaded on
#   `this loaght thing setebul of benonlockant.
#
#   `i how alice loting
# to the simpod, and theay get in the didney agaulded with a long to one roon inangon wo she trouldered she in the tas "ut; ghat three         vrice  mulk thee even'thing at all mighting on, bure said flimbled then once; and she sound rabbe to telrem?' said
# the green sling befose all spe t
#
# ----- diversity: 1.2
# ----- Generating with seed: "nce first--verdict afterwards.'
#
#   `stuf"
# nce first--verdict afterwards.'
#
#   `stufif' the celtake out healk
# went
# are radbin's?a esda, i mundest aboat gidaid oo it-and for, well yot,' she as thit ool
# ne,' pachieds all deerborthen.
#
#   `masterdite.   the laite wat
# at thind
# infowing hreet again
# of be
# non?'
#
#   it said the bext
# oncan it?'
#
#   `i go put she ede'saing per ongered
# in.'
#
#   `of a aghinged pim-mied
# novidgobed nut,'
# said the simben an ever lack.'
#
# arsid alice.  `fight
# the di
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 49502/49502 [==============================] - 59s 1ms/step - loss: 1.5042
#
# ----- diversity: 0.2
# ----- Generating with seed: "hion; and, last of all this
# grand proces"
# hion; and, last of all this
# grand proces and the looked at all the looked at any the last of the larted a little like a miden, and the mock turtle she was began with a little like the leasn the lay had began that she had not all a thing to alice again, and the mock turtle all the looked and the lay had began that she reance, and the mock turtle alice, and the mock turtle she went on in a grow, and the least to see began, and the mock tu
#
# ----- diversity: 0.5
# ----- Generating with seed: "hion; and, last of all this
# grand proces"
# hion; and, last of all this
# grand procesting about again, and a cearse to her here, and and a midned a graps all all a langed went on alice, `i've was begin, and the mock turtle which say a grown of got latt of a
# let like the
# cat a paged a caties a pood, and the
# rack in a grown a
# then the madch had began, and the sall a stapped to be of her the leas again,
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "hion; and, last of all this
# grand proces"
# hion; and, last of all this
# grand proces, and dad great way!  i trie be terss.
#
#   `crett inge take all drow her
# upton sand, its alt leg
# st, love went eck of s he crasking on you drain.
# "alich going side with listle sheese dight, abyou ranstlr thated tham dos
# net she
# reclly:  in the
# back:  the quege, say.
#
#   `i went way, `-i this she surple two houtht tongak all be not
# begon't behund,
# there was goodcly day.  she
# came
# a arch, affer the co
#
# ----- diversity: 1.2
# ----- Generating with seed: "hion; and, last of all this
# grand proces"
# hion; and, last of all this
# grand proces
# grow to this maepedf aoule,
# and charne.
#
#   yot
# don'w
# whet edpos if ey thace with at nigs with
# it
# lartt ,'
# sere, as which wey
# asanchifflyflanaital.
#
#   nfbey had turall fpe, i courdy houst.  the was yourally.
#
#   `but sas:  the yours!' she said
# at a bet!  aid!'
#
#   see ahf it
# rapaithin:  to ras even, alice, anclering to an?' sne kedpd up,       croqueg
# skense to my begining i'
# ne
# th
# negr sagag in con
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 49502/49502 [==============================] - 53s 1ms/step - loss: 1.4271
#
# ----- diversity: 0.2
# ----- Generating with seed: "take a fancy to cats if you could only s"
# take a fancy to cats if you could only she had the might in a going to her and the mock turtle the searly alice was a mine had a mine of the might with a going of the might and the mock turtle with the might in a mine have of the mock turtle had the mock turtle with a might the might with a going to her and the might with a larger the mock turtle she had the might alice, `i don't the might the might in a mine have of the might with a st
#
# ----- diversity: 0.5
# ----- Generating with seed: "take a fancy to cats if you could only s"
# take a fancy to cats if you could only she talking with one of a might.
#
#   `i must the dads of her the begt begin the march hare off herself, `i should remaid to her and him the middre, the duchess, and she said to alice, `the might traing to herself the way the pighing them alice rabbit all stime, `if alice one with one the carnent of the court of the stook the ong of the mock turtle about as she had nothing she had the hatter, and the
#
# ----- diversity: 1.0
# ----- Generating with seed: "take a fancy to cats if you could only s"
# take a fancy to cats if you could only sure hall you kne.  i mocm the birmfures she rtaincty a voig this of the othing to of hightul smblare, the bormouse little
# kist of a
# muchin laiting beginsn's droms
# to grow thill with that tike the dight, who
# oughall of no meganging is.'
# s no have olpoessed, with my called the will botheeg on gatties, thry nened--going him pishoss way
# riesure heuch against me was for said in ther ham, the want as t
#
# ----- diversity: 1.2
# ----- Generating with seed: "take a fancy to cats if you could only s"
# take a fancy to cats if you could only shem-hohise cur:apssiening
# the wind withine withoee thought the mock
# tutter withour ampemmed, for sut ortoed bo onny
# or watcling to say you like.  troumhvourer, repeatided didning crishyroumed room cresseon had nor of g tone, enaim, againle, and to her but stook stited!' said oming about salay all chetting out hitting for cated
# jucking about aline rist her feetbor.
# cet ofte: the kifgo happen, and
# t
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 49502/49502 [==============================] - 53s 1ms/step - loss: 1.6957
#
# ----- diversity: 0.2
# ----- Generating with seed: "ike a stalk out of a sea of green leaves"
# ike a stalk out of a sea of green leaves and the seece and began the seacl again:  `why the did not,' said the king was to the seacl as she was to the gryphon see she was a great had not and the too she was a great had the seeck and the way with a great her head the seets the seece and the seece all see the did not stand the seacl as she was a great rabbit, `i wish the stook the sort of the see she was to see what she was going to alice
#
# ----- diversity: 0.5
# ----- Generating with seed: "ike a stalk out of a sea of green leaves"
# ike a stalk out of a sea of green leaves and stook the stall in a grea-  i'll of the seet the did now, it the sart, `i shan it was rabming time a little was mime the side, `i won't please of year her hand to herself, and she dance.
#
#   `they duch the duchess.'
#
#   `cume see she wrising the taple, they would the sort on the thing mine up and she trows!' said the houre as sure and began sure the back the ploouse on the great his hear was si
#
# ----- diversity: 1.0
# ----- Generating with seed: "ike a stalk out of a sea of green leaves"
# ike a stalk out of a sea of green leaves, `why a vening the evear first of a stable time some mat mear mangs verse cone pleases.'
#
#   `lein
# id; sughing and do with the room on, `i -'
# laby far stlise, but the proves tonem it"'
# loused with ere much every beching very rurrelly of feet from! they
# were brean grinuve
# remembly an ourstied grown; that could sure heartdo to thear mad a stembling the
# jurtt chacking that some mabve the segel.  with
#
# ----- diversity: 1.2
# ----- Generating with seed: "ike a stalk out of a sea of green leaves"
# ike a stalk out of a sea of green leaves!--
#
#     thiyg it
# at the
# epramied
# grean was tooh get-re that have on any suok, vanely buck the
# tout seepubina:
#
#   happed away.'
#
#   `wet twree the livery.  it's cryghy, net in at
# chueves
# of hat toy anoted up:  `--boisseliwly.
#
#   `why, if i'll so two
# a kind
# gottlaking sirsty.
#
#   voilinge washed about divent
# makes lapp, and
# lome.
#    leat engable it they her
# entting itseod                    whise!'
#
#
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 49502/49502 [==============================] - 53s 1ms/step - loss: 1.3020
#
# ----- diversity: 0.2
# ----- Generating with seed: "id
#                     cunning
#          "
# id
#                     cunning
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "id
#                     cunning
#          "
# id
#                     cunning
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "id
#                     cunning
#          "
# id
#                     cunning
#                                       *                               couphe
#             chouried asked, and the elfuce before, and she rememsn'd very rabbin, if i thinking looking up at look.
#
#   `chich mad she swinned eye
# beare, `what a voice.
#
#   `oh! when she toing on,
# whow me she sounder left lowg, say!  `i got bef
# remember
# nothing.
#
#   `who, do bet in
# a gow was shrilk looking,
#  thone, still out and afye
#
# ----- diversity: 1.2
# ----- Generating with seed: "id
#                     cunning
#          "
# id
#                     cunning
#           nace theires fimble
# ?o hound aart of huur offo:  eappone.
#
#   `mong, who
# no beare
# sownginge
# tasking deny pegpely:
#
#   xecroves as te mobets nother.-
# `no--roattle, `dupp he
# very to onen on latthing at quite any taick but
# ween
# forneven had they were decy out old at"emple of alice gotden wheneed of the rabchrup"; `you can've went on?) alice
# book, and sake alice, child being it"    din
# toing not, like
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 49502/49502 [==============================] - 55s 1ms/step - loss: 1.2583
#
# ----- diversity: 0.2
# ----- Generating with seed: "cting to see it again, but it
# did not ap"
# cting to see it again, but it
# did not appeared and the gryphon said to herself, and she was got to the looked at the looked at the poor last and shook at all the gryphon said to the find her hands and way of the back to the garden, and then had begin in a little begin in a little back in a low, and she was got to be our took in a low, to be the book in a little begin in a low, and the gryphon said a tea something to alice, and she seeme
#
# ----- diversity: 0.5
# ----- Generating with seed: "cting to see it again, but it
# did not ap"
# cting to see it again, but it
# did not apoup she had how stay, and the hatter, and had begun in the mouse of go on your in to keet about and began in the began managht in a poor last as she could not and had be list one of grown to the ought to bi gueded but that the good nether in waiting at and a
# little begin, `why said to the game to be a crying about the place of the looked at the
# back these made or bottle could her head of the sea,
#
# ----- diversity: 1.0
# ----- Generating with seed: "cting to see it again, but it
# did not ap"
# cting to see it again, but it
# did not appearred.    `i can't begup in whice back got, you know?'
#
#   `tway throttile!  where stook `to prifevect,' said alice.  it said grown hark, down, and don't ite gover.
#
#   so he dideytoon as it one all consiot at well down in her rypat, and every sounded,
# is my souprotyaust
# went no made alls, in
# set partiful in befout it face.
#
#   `then't through rabst be
# the resomuch got in her my someting doin me
# a
#
# ----- diversity: 1.2
# ----- Generating with seed: "cting to see it again, but it
# did not ap"
# cting to see it again, but it
# did not apial him
# them---eh-epose milesy,' thone they, as on
# moarning said in a you-pon to
# geared in thetred read, it
# won't letti'l,   through blaus?  it's no begin.'
#
#   `it
# you know,' wenen the why alacrsaidly,
# selliare of got `isg!' wa litele:  `but for the king in sight;
# and of  eveg way of theo,' said
# d
# alice tils the sunders well, rounds.  now be foor:  `--no--if cumides as a geng xage
# ofrent, with the
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 19200/49502 [==========>...................] - ETA: 41s - loss: 1.1928
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/github/nlp-course-instructor/09_classification_deep_learning/lstm_text_generation.py in <module>()
#      77     model.fit(X, y,
#      78               batch_size=128,
# ---> 79               epochs=1)
#      80
#      81     start_index = random.randint(0, len(text) - maxlen - 1)
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/nlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
