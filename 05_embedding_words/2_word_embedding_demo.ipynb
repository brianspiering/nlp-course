# %% [markdown]
# Let's do some Deep Learning!
# -----

# %% [markdown]
# <center><img src="images/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ----
# Apply word2vec to a dataset
# -----
#
# Overview:
#
# 1. Download some training data
# 1. Setup word2vec model in TensorFlow
# 1. Train on the data
# 1. Visualize the result
#
# This notebook is based on a [TensorFlow tutorial for word2vec](https://github.com/tensorflow/tensorflow/edit/r1.4/tensorflow/examples/tutorials/word2vec/word2vec_basic.py).

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ----
# Step 1: Download the data.
# ----

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# While this code ☝️  is running ⏳, preview the code ahead 🔍.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# Notice: None of the words are capitalized and there is no punctuation.
#
# Preprocessing is an art. It depends on your raw data and how you plan to use your final data. You might want to encode ngrams, instead of just splitting all items into unigrams.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# Variable Legend
# ------
# data - list of codes (integers from 0 to vocabulary_size-1).
#     This is the original text but words are replaced by their codes
#
# count - map of words(strings) to count of occurrences
#
# dictionary - map of words(strings) to their codes(integers)
#
# reverse_dictionary - maps codes(integers) to words(strings)

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Most least words:')
print(*count[-5:], sep="\n")
# Out:
# Most least words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ----
# Step 3: Function to generate a training batch for the skip-gram model.
# -----

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = tf.global_variables_initializer()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  270.3956298828125
# Nearest to 'these': grossing, patient, plates, croatia,
# Nearest to 'of': entrenchment, newborns, hata, nai,
# Nearest to 'more': simile, inca, nihilism, improbable,
# Nearest to 'one': haynes, transform, catamaran, noses,
# Nearest to 'american': oligarchic, dependents, sherbrooke, schweitzer,
# Nearest to 'about': whence, pup, deemed, martinique,
# Nearest to 'during': della, blackbird, kuala, plutinos,
# Nearest to 'united': gilman, diogo, kibbutz, nodes,
# Nearest to 'six': bretons, dorff, chernenko, maimonides,
# Nearest to 'd': improvements, bestiary, creeks, guidebook,
# Nearest to 'three': fictionalized, entendre, demo, summertime,
# Nearest to 'he': contemplated, supervisors, development, fireworks,
# Nearest to 'into': motivation, annuity, nord, mujahedeen,
# Nearest to 'all': collapsing, crispin, available, humorist,
# Nearest to 'from': devotees, subatomic, mondial, boundary,
# Nearest to 'time': fly, unison, chimp, diplomacy,
#
# Average loss at step  2000 :  113.6045593738556
# Nearest to 'these': early, patient, h, space,
# Nearest to 'of': in, the, and, by,
# Nearest to 'more': persepolis, extension, stress, layout,
# Nearest to 'one': kill, and, cc, particular,
# Nearest to 'american': novels, term, beginning, wife,
# Nearest to 'about': achieved, scrimmage, package, lay,
# Nearest to 'during': contains, written, mostly, united,
# Nearest to 'united': independence, making, find, in,
# Nearest to 'six': time, do, genre, professional,
# Nearest to 'd': electronic, sympathetic, taken, lift,
# Nearest to 'three': eight, boys, energy, dojo,
# Nearest to 'he': development, done, symbol, camera,
# Nearest to 'into': what, motivation, references, terminate,
# Nearest to 'all': available, pass, belt, pamphlet,
# Nearest to 'from': father, boundary, emergency, above,
# Nearest to 'time': awards, fly, set, finished,
#
# Average loss at step  4000 :  52.62087731313706
# Nearest to 'these': lymphoma, patient, early, rich,
# Nearest to 'of': in, and, the, presenting,
# Nearest to 'more': extension, improbable, acquired, seyss,
# Nearest to 'one': UNK, markov, climax, psi,
# Nearest to 'american': novels, gimme, sarris, caribbean,
# Nearest to 'about': therapists, achieved, deemed, myth,
# Nearest to 'during': contains, written, neurological, losses,
# Nearest to 'united': coke, independence, making, therefore,
# Nearest to 'six': nine, genre, seven, bang,
# Nearest to 'd': UNK, electronic, improvements, sympathetic,
# Nearest to 'three': onset, eight, boys, altenberg,
# Nearest to 'he': development, ho, fought, done,
# Nearest to 'into': motivation, what, methadone, spp,
# Nearest to 'all': available, crispin, acid, pamphlet,
# Nearest to 'from': father, subatomic, bras, above,
# Nearest to 'time': awards, coke, diplomacy, finished,
#
# Average loss at step  6000 :  33.87665755963325
# Nearest to 'these': patient, lymphoma, early, rich,
# Nearest to 'of': in, and, the, by,
# Nearest to 'more': lysander, jakob, extension, acquired,
# Nearest to 'one': nine, zero, two, archie,
# Nearest to 'american': schweitzer, caribbean, novels, gimme,
# Nearest to 'about': therapists, achieved, one, myth,
# Nearest to 'during': contains, written, neurological, losses,
# Nearest to 'united': coke, independence, making, in,
# Nearest to 'six': nine, grandparents, carnival, zero,
# Nearest to 'd': UNK, improvements, observance, meticulous,
# Nearest to 'three': eight, onset, one, altenberg,
# Nearest to 'he': covenant, and, development, patient,
# Nearest to 'into': motivation, spp, what, methadone,
# Nearest to 'all': available, crispin, acid, pamphlet,
# Nearest to 'from': and, of, in, father,
# Nearest to 'time': awards, coke, diplomacy, fly,
#
# Average loss at step  8000 :  23.683463305711747
# Nearest to 'these': lymphoma, patient, the, early,
# Nearest to 'of': and, in, by, the,
# Nearest to 'more': jakob, lysander, muhammad, improbable,
# Nearest to 'one': gollancz, two, nine, and,
# Nearest to 'american': schweitzer, and, caribbean, oligarchic,
# Nearest to 'about': gollancz, therapists, achieved, hephaestus,
# Nearest to 'during': contains, neurological, written, biblical,
# Nearest to 'united': coke, in, making, independence,
# Nearest to 'six': nine, zero, one, gollancz,
# Nearest to 'd': subkey, observance, kilda, UNK,
# Nearest to 'three': eight, two, altenberg, six,
# Nearest to 'he': and, covenant, they, it,
# Nearest to 'into': motivation, spp, methadone, what,
# Nearest to 'all': available, acid, crispin, pamphlet,
# Nearest to 'from': in, and, of, father,
# Nearest to 'time': awards, coke, lowlands, suburban,
#
# Average loss at step  10000 :  18.025205147266387
# Nearest to 'these': lymphoma, patient, dasyprocta, agouti,
# Nearest to 'of': and, in, from, agouti,
# Nearest to 'more': agouti, dasyprocta, jakob, muhammad,
# Nearest to 'one': circ, agouti, dasyprocta, two,
# Nearest to 'american': schweitzer, and, dasyprocta, caribbean,
# Nearest to 'about': circ, agouti, gollancz, whence,
# Nearest to 'during': agouti, contains, neurological, biblical,
# Nearest to 'united': circ, agouti, coke, dasyprocta,
# Nearest to 'six': dasyprocta, nine, circ, zero,
# Nearest to 'd': dasyprocta, subkey, one, observance,
# Nearest to 'three': circ, dasyprocta, agouti, two,
# Nearest to 'he': and, they, it, covenant,
# Nearest to 'into': motivation, spp, circ, prejudice,
# Nearest to 'all': available, crispin, acid, pamphlet,
# Nearest to 'from': in, of, and, to,
# Nearest to 'time': dasyprocta, agouti, coke, awards,
#
# Average loss at step  12000 :  14.019905438542366
# Nearest to 'these': lymphoma, patient, dasyprocta, agouti,
# Nearest to 'of': in, and, from, s,
# Nearest to 'more': agouti, muhammad, dasyprocta, jakob,
# Nearest to 'one': circ, two, agouti, dasyprocta,
# Nearest to 'american': and, schweitzer, dasyprocta, agouti,
# Nearest to 'about': one, whence, circ, gollancz,
# Nearest to 'during': agouti, contains, domitius, neurological,
# Nearest to 'united': coke, circ, agouti, in,
# Nearest to 'six': nine, dasyprocta, zero, circ,
# Nearest to 'd': dasyprocta, subkey, b, observance,
# Nearest to 'three': one, circ, eight, two,
# Nearest to 'he': and, they, it, linkages,
# Nearest to 'into': spp, motivation, of, circ,
# Nearest to 'all': available, crispin, pamphlet, acid,
# Nearest to 'from': of, in, and, to,
# Nearest to 'time': dasyprocta, agouti, coke, awards,
#
# Average loss at step  14000 :  11.185410977721215
# Nearest to 'these': lymphoma, dasyprocta, agouti, patient,
# Nearest to 'of': in, and, from, s,
# Nearest to 'more': muhammad, agouti, dasyprocta, jakob,
# Nearest to 'one': circ, agouti, dasyprocta, two,
# Nearest to 'american': and, schweitzer, one, dasyprocta,
# Nearest to 'about': whence, circ, gollancz, alamanni,
# Nearest to 'during': agouti, contains, domitius, della,
# Nearest to 'united': circ, coke, agouti, dasyprocta,
# Nearest to 'six': nine, dasyprocta, eight, zero,
# Nearest to 'd': b, and, dasyprocta, one,
# Nearest to 'three': eight, circ, dasyprocta, agouti,
# Nearest to 'he': and, they, it, linkages,
# Nearest to 'into': spp, motivation, of, and,
# Nearest to 'all': available, crispin, pamphlet, acid,
# Nearest to 'from': of, in, and, by,
# Nearest to 'time': dasyprocta, agouti, coke, awards,
#
# Average loss at step  16000 :  9.890092159509658
# Nearest to 'these': truetype, lymphoma, patient, the,
# Nearest to 'of': and, in, for, from,
# Nearest to 'more': muhammad, agouti, jakob, lysander,
# Nearest to 'one': two, circ, nine, agouti,
# Nearest to 'american': schweitzer, and, dasyprocta, agouti,
# Nearest to 'about': circ, whence, agouti, gollancz,
# Nearest to 'during': agouti, contains, domitius, biblical,
# Nearest to 'united': circ, coke, agouti, dasyprocta,
# Nearest to 'six': nine, eight, zero, seven,
# Nearest to 'd': b, truetype, dasyprocta, and,
# Nearest to 'three': eight, two, nine, seven,
# Nearest to 'he': it, they, and, truetype,
# Nearest to 'into': mujahedeen, spp, motivation, of,
# Nearest to 'all': available, crispin, pamphlet, acid,
# Nearest to 'from': in, and, of, by,
# Nearest to 'time': dasyprocta, agouti, coke, lowlands,
#
# Average loss at step  18000 :  8.425723392009735
# Nearest to 'these': truetype, lymphoma, dasyprocta, agouti,
# Nearest to 'of': in, and, for, from,
# Nearest to 'more': muhammad, agouti, jakob, lysander,
# Nearest to 'one': two, circ, agouti, four,
# Nearest to 'american': schweitzer, and, dasyprocta, s,
# Nearest to 'about': whence, one, circ, alamanni,
# Nearest to 'during': agouti, contains, domitius, in,
# Nearest to 'united': coke, circ, agouti, making,
# Nearest to 'six': nine, eight, dasyprocta, zero,
# Nearest to 'd': b, and, observance, truetype,
# Nearest to 'three': two, eight, four, dasyprocta,
# Nearest to 'he': it, they, and, truetype,
# Nearest to 'into': spp, mujahedeen, motivation, circ,
# Nearest to 'all': crispin, available, three, pamphlet,
# Nearest to 'from': in, and, of, to,
# Nearest to 'time': coke, dasyprocta, agouti, suburban,
#
# Average loss at step  20000 :  7.847724373340607
# Nearest to 'these': truetype, the, lymphoma, dasyprocta,
# Nearest to 'of': in, and, for, from,
# Nearest to 'more': muhammad, agouti, jakob, lysander,
# Nearest to 'one': two, circ, agouti, dasyprocta,
# Nearest to 'american': and, schweitzer, dasyprocta, one,
# Nearest to 'about': whence, circ, gollancz, alamanni,
# Nearest to 'during': in, agouti, contains, domitius,
# Nearest to 'united': coke, circ, in, nodes,
# Nearest to 'six': nine, eight, five, zero,
# Nearest to 'd': b, and, UNK, observance,
# Nearest to 'three': two, eight, six, seven,
# Nearest to 'he': it, they, and, truetype,
# Nearest to 'into': spp, mujahedeen, motivation, and,
# Nearest to 'all': crispin, available, three, pamphlet,
# Nearest to 'from': in, and, of, by,
# Nearest to 'time': coke, dasyprocta, agouti, suburban,
#
# Average loss at step  22000 :  7.421956856131554
# Nearest to 'these': truetype, the, lymphoma, many,
# Nearest to 'of': in, and, for, from,
# Nearest to 'more': muhammad, agouti, jakob, lysander,
# Nearest to 'one': two, circ, eight, four,
# Nearest to 'american': and, schweitzer, dasyprocta, s,
# Nearest to 'about': circ, whence, agouti, gollancz,
# Nearest to 'during': in, agouti, contains, of,
# Nearest to 'united': coke, circ, in, agouti,
# Nearest to 'six': eight, five, nine, seven,
# Nearest to 'd': b, and, observance, american,
# Nearest to 'three': eight, four, seven, two,
# Nearest to 'he': it, they, she, truetype,
# Nearest to 'into': spp, and, by, mujahedeen,
# Nearest to 'all': crispin, available, three, agouti,
# Nearest to 'from': in, of, and, by,
# Nearest to 'time': coke, dasyprocta, agouti, suburban,
#
# Average loss at step  24000 :  6.95190269100666
# Nearest to 'these': truetype, many, lymphoma, the,
# Nearest to 'of': in, and, for, from,
# Nearest to 'more': muhammad, agouti, jakob, lysander,
# Nearest to 'one': two, circ, four, eight,
# Nearest to 'american': and, schweitzer, dasyprocta, s,
# Nearest to 'about': circ, agouti, whence, gollancz,
# Nearest to 'during': in, and, contains, of,
# Nearest to 'united': coke, circ, of, agouti,
# Nearest to 'six': eight, five, seven, nine,
# Nearest to 'd': b, and, observance, american,
# Nearest to 'three': eight, five, two, four,
# Nearest to 'he': it, they, she, and,
# Nearest to 'into': spp, by, mujahedeen, and,
# Nearest to 'all': crispin, available, pamphlet, three,
# Nearest to 'from': in, of, and, for,
# Nearest to 'time': coke, agouti, dasyprocta, suburban,
#
# Average loss at step  26000 :  6.276894285559655
# Nearest to 'these': truetype, many, lymphoma, dasyprocta,
# Nearest to 'of': and, in, for, from,
# Nearest to 'more': muhammad, agouti, jakob, precedent,
# Nearest to 'one': two, four, circ, agouti,
# Nearest to 'american': and, schweitzer, dasyprocta, one,
# Nearest to 'about': whence, circ, alamanni, agouti,
# Nearest to 'during': in, and, on, agouti,
# Nearest to 'united': coke, circ, in, agouti,
# Nearest to 'six': eight, five, nine, seven,
# Nearest to 'd': b, and, one, observance,
# Nearest to 'three': eight, four, five, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': by, spp, from, mujahedeen,
# Nearest to 'all': crispin, available, three, pamphlet,
# Nearest to 'from': in, by, for, and,
# Nearest to 'time': coke, agouti, dasyprocta, suburban,
#
# Average loss at step  28000 :  6.332298988342285
# Nearest to 'these': truetype, many, the, lymphoma,
# Nearest to 'of': and, in, for, s,
# Nearest to 'more': muhammad, agouti, jakob, precedent,
# Nearest to 'one': two, four, circ, six,
# Nearest to 'american': schweitzer, and, dasyprocta, agouti,
# Nearest to 'about': whence, alamanni, circ, gollancz,
# Nearest to 'during': in, on, and, agouti,
# Nearest to 'united': coke, in, circ, agouti,
# Nearest to 'six': eight, five, seven, nine,
# Nearest to 'd': b, observance, UNK, dasyprocta,
# Nearest to 'three': five, eight, seven, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, mujahedeen,
# Nearest to 'all': crispin, agouti, pamphlet, available,
# Nearest to 'from': in, and, of, by,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
#
# Average loss at step  30000 :  6.005027281880379
# Nearest to 'these': truetype, many, the, grossing,
# Nearest to 'of': and, for, in, nine,
# Nearest to 'more': muhammad, agouti, jakob, precedent,
# Nearest to 'one': two, three, four, circ,
# Nearest to 'american': and, schweitzer, dasyprocta, agouti,
# Nearest to 'about': circ, whence, gollancz, agouti,
# Nearest to 'during': in, on, and, agouti,
# Nearest to 'united': in, coke, circ, agouti,
# Nearest to 'six': five, eight, seven, three,
# Nearest to 'd': b, observance, securities, dasyprocta,
# Nearest to 'three': five, six, two, seven,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, mujahedeen,
# Nearest to 'all': crispin, pamphlet, available, agouti,
# Nearest to 'from': in, and, on, by,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
#
# Average loss at step  32000 :  6.09488305735588
# Nearest to 'these': many, truetype, grossing, such,
# Nearest to 'of': for, in, nine, and,
# Nearest to 'more': muhammad, jakob, precedent, agouti,
# Nearest to 'one': two, three, four, seven,
# Nearest to 'american': and, schweitzer, dasyprocta, dexter,
# Nearest to 'about': alamanni, agouti, circ, whence,
# Nearest to 'during': in, on, agouti, contains,
# Nearest to 'united': coke, in, circ, agouti,
# Nearest to 'six': eight, five, seven, four,
# Nearest to 'd': b, and, UNK, securities,
# Nearest to 'three': five, two, seven, four,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, in,
# Nearest to 'all': crispin, agouti, pamphlet, available,
# Nearest to 'from': in, on, and, by,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
#
# Average loss at step  34000 :  5.722779929995537
# Nearest to 'these': many, truetype, grossing, such,
# Nearest to 'of': and, in, for, nine,
# Nearest to 'more': muhammad, agouti, jakob, precedent,
# Nearest to 'one': two, three, four, six,
# Nearest to 'american': and, schweitzer, dasyprocta, dexter,
# Nearest to 'about': circ, agouti, gollancz, alamanni,
# Nearest to 'during': in, on, agouti, contains,
# Nearest to 'united': in, coke, circ, agouti,
# Nearest to 'six': eight, seven, five, four,
# Nearest to 'd': b, securities, observance, improbable,
# Nearest to 'three': five, four, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, in,
# Nearest to 'all': crispin, agouti, pamphlet, available,
# Nearest to 'from': in, on, by, and,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
#
# Average loss at step  36000 :  5.4956631462574
# Nearest to 'these': many, truetype, grossing, some,
# Nearest to 'of': in, zero, and, altenberg,
# Nearest to 'more': muhammad, agouti, precedent, jakob,
# Nearest to 'one': two, four, three, seven,
# Nearest to 'american': and, schweitzer, dasyprocta, british,
# Nearest to 'about': circ, four, whence, gollancz,
# Nearest to 'during': in, on, contains, of,
# Nearest to 'united': coke, in, circ, agouti,
# Nearest to 'six': eight, seven, five, four,
# Nearest to 'd': b, and, UNK, securities,
# Nearest to 'three': four, five, eight, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, in,
# Nearest to 'all': crispin, agouti, pamphlet, dasyprocta,
# Nearest to 'from': in, on, of, by,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
#
# Average loss at step  38000 :  5.486829243540764
# Nearest to 'these': many, truetype, such, some,
# Nearest to 'of': in, johansson, altenberg, from,
# Nearest to 'more': muhammad, agouti, precedent, jakob,
# Nearest to 'one': two, seven, four, agouti,
# Nearest to 'american': and, dasyprocta, UNK, schweitzer,
# Nearest to 'about': whence, alamanni, circ, four,
# Nearest to 'during': in, on, agouti, contains,
# Nearest to 'united': coke, circ, agouti, in,
# Nearest to 'six': eight, seven, four, five,
# Nearest to 'd': b, UNK, securities, observance,
# Nearest to 'three': five, four, six, seven,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, by, spp, mujahedeen,
# Nearest to 'all': three, crispin, agouti, available,
# Nearest to 'from': in, above, of, on,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
# Average loss at step  40000 :  5.360192214608192
# Nearest to 'these': many, some, such, truetype,
# Nearest to 'of': johansson, and, in, altenberg,
# Nearest to 'more': muhammad, precedent, agouti, jakob,
# Nearest to 'one': two, four, agouti, six,
# Nearest to 'american': and, dasyprocta, british, schweitzer,
# Nearest to 'about': four, alamanni, whence, circ,
# Nearest to 'during': in, on, agouti, contains,
# Nearest to 'united': coke, circ, agouti, dasyprocta,
# Nearest to 'six': five, eight, four, seven,
# Nearest to 'd': b, UNK, securities, observance,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, mujahedeen,
# Nearest to 'all': three, crispin, agouti, pamphlet,
# Nearest to 'from': in, of, above, on,
# Nearest to 'time': coke, agouti, dasyprocta, lowlands,
#
# Average loss at step  42000 :  5.363495557427406
# Nearest to 'these': many, some, such, truetype,
# Nearest to 'of': johansson, in, nine, altenberg,
# Nearest to 'more': muhammad, agouti, very, precedent,
# Nearest to 'one': two, four, agouti, five,
# Nearest to 'american': and, dasyprocta, british, schweitzer,
# Nearest to 'about': four, alamanni, circ, agouti,
# Nearest to 'during': in, on, agouti, of,
# Nearest to 'united': coke, in, circ, agouti,
# Nearest to 'six': eight, five, four, three,
# Nearest to 'd': b, UNK, securities, dasyprocta,
# Nearest to 'three': five, four, two, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, circ,
# Nearest to 'all': three, agouti, four, dasyprocta,
# Nearest to 'from': in, of, above, for,
# Nearest to 'time': agouti, coke, dasyprocta, trough,
#
# Average loss at step  44000 :  5.335732743859291
# Nearest to 'these': many, some, such, grossing,
# Nearest to 'of': in, and, johansson, for,
# Nearest to 'more': muhammad, very, agouti, precedent,
# Nearest to 'one': two, four, six, three,
# Nearest to 'american': and, dasyprocta, schweitzer, british,
# Nearest to 'about': alamanni, circ, agouti, gollancz,
# Nearest to 'during': in, on, agouti, infante,
# Nearest to 'united': coke, ossie, requirement, circ,
# Nearest to 'six': eight, four, five, seven,
# Nearest to 'd': b, UNK, securities, adamson,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, in, by,
# Nearest to 'all': three, agouti, eukaryotic, four,
# Nearest to 'from': in, of, above, by,
# Nearest to 'time': coke, agouti, dasyprocta, trough,
#
# Average loss at step  46000 :  5.0354576365947725
# Nearest to 'these': many, some, such, the,
# Nearest to 'of': for, johansson, in, and,
# Nearest to 'more': muhammad, very, precedent, jakob,
# Nearest to 'one': two, four, three, six,
# Nearest to 'american': dasyprocta, and, british, one,
# Nearest to 'about': five, four, alamanni, circ,
# Nearest to 'during': in, on, for, agouti,
# Nearest to 'united': coke, circ, agouti, nodes,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, four, securities, adamson,
# Nearest to 'three': four, five, two, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, around,
# Nearest to 'all': three, four, agouti, eukaryotic,
# Nearest to 'from': in, of, above, for,
# Nearest to 'time': coke, agouti, dasyprocta, trough,
#
# Average loss at step  48000 :  5.131373031139374
# Nearest to 'these': many, some, such, several,
# Nearest to 'of': in, and, for, johansson,
# Nearest to 'more': muhammad, very, agouti, precedent,
# Nearest to 'one': two, six, four, three,
# Nearest to 'american': and, british, schweitzer, including,
# Nearest to 'about': four, circ, agouti, alamanni,
# Nearest to 'during': in, on, agouti, and,
# Nearest to 'united': coke, circ, agouti, nodes,
# Nearest to 'six': eight, four, five, seven,
# Nearest to 'd': b, securities, and, UNK,
# Nearest to 'three': four, five, two, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, around,
# Nearest to 'all': three, agouti, eukaryotic, four,
# Nearest to 'from': in, into, and, above,
# Nearest to 'time': thibetanus, coke, agouti, dasyprocta,
#
# Average loss at step  50000 :  5.28276359641552
# Nearest to 'these': many, some, such, several,
# Nearest to 'of': johansson, in, altenberg, including,
# Nearest to 'more': muhammad, very, most, agouti,
# Nearest to 'one': two, six, eight, three,
# Nearest to 'american': british, dasyprocta, including, schweitzer,
# Nearest to 'about': four, five, circ, agouti,
# Nearest to 'during': in, on, of, and,
# Nearest to 'united': coke, wct, circ, requirement,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, UNK, securities, four,
# Nearest to 'three': five, two, four, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, around,
# Nearest to 'all': three, agouti, dasyprocta, eukaryotic,
# Nearest to 'from': in, into, above, of,
# Nearest to 'time': thibetanus, coke, agouti, dasyprocta,
#
# Average loss at step  52000 :  5.121322431683541
# Nearest to 'these': many, some, such, several,
# Nearest to 'of': johansson, for, in, nine,
# Nearest to 'more': muhammad, very, most, precedent,
# Nearest to 'one': two, three, four, six,
# Nearest to 'american': british, and, including, dasyprocta,
# Nearest to 'about': four, alamanni, five, circ,
# Nearest to 'during': in, on, and, agouti,
# Nearest to 'united': coke, wct, circ, requirement,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, UNK, securities, and,
# Nearest to 'three': four, five, two, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, around,
# Nearest to 'all': three, agouti, eukaryotic, dasyprocta,
# Nearest to 'from': in, into, above, for,
# Nearest to 'time': thibetanus, coke, agouti, trough,
#
# Average loss at step  54000 :  5.084135940909386
# Nearest to 'these': many, some, such, several,
# Nearest to 'of': in, johansson, nine, including,
# Nearest to 'more': very, tadeusz, muhammad, most,
# Nearest to 'one': two, three, four, six,
# Nearest to 'american': british, and, including, djvu,
# Nearest to 'about': four, five, circ, alamanni,
# Nearest to 'during': in, on, agouti, of,
# Nearest to 'united': coke, gilman, wct, circ,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, UNK, and, securities,
# Nearest to 'three': four, two, five, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, around, by,
# Nearest to 'all': three, agouti, michelob, two,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thibetanus, coke, agouti, trough,
#
# Average loss at step  56000 :  4.997899811148644
# Nearest to 'these': some, many, such, two,
# Nearest to 'of': nine, johansson, in, for,
# Nearest to 'more': very, muhammad, tadeusz, most,
# Nearest to 'one': two, four, agouti, six,
# Nearest to 'american': british, and, including, dasyprocta,
# Nearest to 'about': four, five, alamanni, that,
# Nearest to 'during': in, on, agouti, biblical,
# Nearest to 'united': wct, coke, gilman, circ,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, UNK, securities, h,
# Nearest to 'three': four, two, five, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, designate,
# Nearest to 'all': three, michelob, agouti, two,
# Nearest to 'from': in, into, after, under,
# Nearest to 'time': thibetanus, coke, agouti, dasyprocta,
#
# Average loss at step  58000 :  5.066012822985649
# Nearest to 'these': some, many, such, other,
# Nearest to 'of': johansson, in, and, nine,
# Nearest to 'more': very, muhammad, tadeusz, most,
# Nearest to 'one': two, four, three, six,
# Nearest to 'american': british, and, cebus, including,
# Nearest to 'about': four, alamanni, circ, agouti,
# Nearest to 'during': in, on, agouti, biblical,
# Nearest to 'united': wct, gilman, coke, circ,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, UNK, callithrix, securities,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, around, by,
# Nearest to 'all': three, agouti, michelob, some,
# Nearest to 'from': in, into, and, on,
# Nearest to 'time': thibetanus, coke, agouti, dasyprocta,
#
# Average loss at step  60000 :  4.893479067504406
# Nearest to 'these': many, some, such, several,
# Nearest to 'of': johansson, mitral, thibetanus, for,
# Nearest to 'more': very, muhammad, tadeusz, most,
# Nearest to 'one': two, four, six, three,
# Nearest to 'american': british, cebus, including, and,
# Nearest to 'about': four, five, circ, agouti,
# Nearest to 'during': in, on, after, of,
# Nearest to 'united': wct, gilman, coke, circ,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, callithrix, securities, h,
# Nearest to 'three': four, five, two, six,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, spp, by, around,
# Nearest to 'all': three, agouti, michelob, some,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thibetanus, agouti, dasyprocta, coke,
#
# Average loss at step  62000 :  4.639290162205696
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, mitral, thibetanus, for,
# Nearest to 'more': very, muhammad, tadeusz, most,
# Nearest to 'one': two, four, agouti, six,
# Nearest to 'american': british, cebus, including, and,
# Nearest to 'about': four, six, circ, five,
# Nearest to 'during': in, on, after, agouti,
# Nearest to 'united': wct, coke, circ, gilman,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, callithrix, UNK, securities,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, with, spp, in,
# Nearest to 'all': three, some, agouti, michelob,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thibetanus, agouti, coke, dasyprocta,
#
# Average loss at step  64000 :  5.022129376530647
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, for, thibetanus, including,
# Nearest to 'more': very, muhammad, tadeusz, less,
# Nearest to 'one': two, four, six, five,
# Nearest to 'american': british, and, cebus, including,
# Nearest to 'about': four, alamanni, gollancz, that,
# Nearest to 'during': in, thaler, on, after,
# Nearest to 'united': thaler, gilman, wct, coke,
# Nearest to 'six': eight, five, four, seven,
# Nearest to 'd': b, UNK, callithrix, securities,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, around, designate, spp,
# Nearest to 'all': some, agouti, three, dinar,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, thibetanus, coke, agouti,
#
# Average loss at step  66000 :  4.9384576528072355
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, including, thibetanus, for,
# Nearest to 'more': very, less, most, muhammad,
# Nearest to 'one': two, four, six, five,
# Nearest to 'american': and, british, including, cebus,
# Nearest to 'about': four, alamanni, gollancz, five,
# Nearest to 'during': in, thaler, on, after,
# Nearest to 'united': thaler, gilman, wct, coke,
# Nearest to 'six': eight, four, five, seven,
# Nearest to 'd': b, UNK, callithrix, h,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, designate, around, with,
# Nearest to 'all': some, three, agouti, dinar,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, thibetanus, coke, agouti,
#
# Average loss at step  68000 :  4.791090624451638
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, for, thibetanus, mitral,
# Nearest to 'more': very, most, less, muhammad,
# Nearest to 'one': two, six, four, three,
# Nearest to 'american': and, british, cebus, including,
# Nearest to 'about': four, alamanni, that, gollancz,
# Nearest to 'during': in, thaler, on, after,
# Nearest to 'united': thaler, gilman, wct, protect,
# Nearest to 'six': eight, four, five, seven,
# Nearest to 'd': b, callithrix, h, securities,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, designate, around, with,
# Nearest to 'all': some, agouti, three, michelob,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, thibetanus, agouti, coke,
#
# Average loss at step  70000 :  4.848193912625312
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, for, mitral, thibetanus,
# Nearest to 'more': very, most, less, muhammad,
# Nearest to 'one': four, two, six, seven,
# Nearest to 'american': british, including, cebus, engineering,
# Nearest to 'about': four, alamanni, that, six,
# Nearest to 'during': in, thaler, on, after,
# Nearest to 'united': gilman, thaler, protect, angkor,
# Nearest to 'six': four, eight, five, seven,
# Nearest to 'd': b, h, callithrix, securities,
# Nearest to 'three': four, five, six, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, around, designate, spp,
# Nearest to 'all': some, three, agouti, many,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, thibetanus, agouti, dasyprocta,
#
# Average loss at step  72000 :  4.7452429996728895
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, in, including, thibetanus,
# Nearest to 'more': very, most, less, tadeusz,
# Nearest to 'one': six, four, two, seven,
# Nearest to 'american': british, and, including, cebus,
# Nearest to 'about': four, alamanni, gollancz, that,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, angkor, thaler,
# Nearest to 'six': four, eight, five, seven,
# Nearest to 'd': b, h, callithrix, securities,
# Nearest to 'three': five, four, six, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, in, spp,
# Nearest to 'all': some, many, agouti, three,
# Nearest to 'from': in, into, under, of,
# Nearest to 'time': thaler, thibetanus, agouti, dasyprocta,
#
# Average loss at step  74000 :  4.826852162361145
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, johansson, thibetanus, for,
# Nearest to 'more': very, most, less, tadeusz,
# Nearest to 'one': four, six, two, three,
# Nearest to 'american': british, including, cebus, engineering,
# Nearest to 'about': four, gollancz, circ, agouti,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, angkor,
# Nearest to 'six': eight, four, seven, five,
# Nearest to 'd': b, h, callithrix, securities,
# Nearest to 'three': six, four, five, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, spp, designate,
# Nearest to 'all': some, many, agouti, michelob,
# Nearest to 'from': in, under, into, by,
# Nearest to 'time': thaler, thibetanus, agouti, dasyprocta,
#
# Average loss at step  76000 :  4.839130211353302
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, johansson, thibetanus, in,
# Nearest to 'more': very, less, most, tadeusz,
# Nearest to 'one': two, six, seven, three,
# Nearest to 'american': british, including, cebus, djvu,
# Nearest to 'about': four, gollancz, alamanni, thibetanus,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, thaler, protect, angkor,
# Nearest to 'six': five, eight, four, seven,
# Nearest to 'd': b, UNK, callithrix, h,
# Nearest to 'three': six, four, five, two,
# Nearest to 'he': it, they, she, who,
# Nearest to 'into': from, around, designate, fingerprints,
# Nearest to 'all': some, many, agouti, three,
# Nearest to 'from': in, under, into, by,
# Nearest to 'time': thaler, agouti, thibetanus, fachhochschule,
#
# Average loss at step  78000 :  4.791125327348709
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, including, nine, mitral,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': two, six, seven, three,
# Nearest to 'american': british, including, cebus, dasyprocta,
# Nearest to 'about': four, gollancz, circ, five,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, wct,
# Nearest to 'six': five, four, seven, eight,
# Nearest to 'd': b, callithrix, h, UNK,
# Nearest to 'three': six, five, four, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, designate, with,
# Nearest to 'all': some, many, three, agouti,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, agouti, dasyprocta, thibetanus,
#
# Average loss at step  80000 :  4.797555185556412
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, including, thibetanus, mitral,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': two, three, six, four,
# Nearest to 'american': british, including, cebus, djvu,
# Nearest to 'about': four, six, gollancz, agouti,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': protect, gilman, thaler, wct,
# Nearest to 'six': five, four, seven, eight,
# Nearest to 'd': b, h, UNK, callithrix,
# Nearest to 'three': four, six, five, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, with, in,
# Nearest to 'all': some, agouti, many, several,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, trough, dasyprocta, thibetanus,
# Average loss at step  82000 :  4.807902302742004
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, johansson, in, thibetanus,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': two, six, three, seven,
# Nearest to 'american': british, including, cebus, djvu,
# Nearest to 'about': four, that, gollancz, aren,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, wct,
# Nearest to 'six': four, five, seven, eight,
# Nearest to 'd': b, h, callithrix, UNK,
# Nearest to 'three': four, two, six, five,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, with, through,
# Nearest to 'all': some, three, agouti, many,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, dasyprocta, fachhochschule, trough,
#
# Average loss at step  84000 :  4.755993371605873
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, including, calypso, mitral,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': two, four, three, six,
# Nearest to 'american': british, including, cebus, djvu,
# Nearest to 'about': four, gollancz, thibetanus, over,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, wct,
# Nearest to 'six': seven, five, four, eight,
# Nearest to 'd': b, h, callithrix, UNK,
# Nearest to 'three': four, six, five, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, through, with,
# Nearest to 'all': some, agouti, several, many,
# Nearest to 'from': in, into, under, after,
# Nearest to 'time': thaler, trough, fachhochschule, dasyprocta,
#
# Average loss at step  86000 :  4.751829270601273
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, including, thibetanus, in,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': four, two, three, seven,
# Nearest to 'american': british, including, cebus, djvu,
# Nearest to 'about': over, four, gollancz, aren,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, wct,
# Nearest to 'six': seven, eight, five, four,
# Nearest to 'd': b, UNK, h, callithrix,
# Nearest to 'three': four, five, two, seven,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, with, through,
# Nearest to 'all': some, many, several, agouti,
# Nearest to 'from': in, into, under, fingerprints,
# Nearest to 'time': thaler, trough, fachhochschule, dasyprocta,
#
# Average loss at step  88000 :  4.66767454791069
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': johansson, in, including, thibetanus,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': seven, two, five, four,
# Nearest to 'american': british, including, cebus, djvu,
# Nearest to 'about': over, that, gollancz, aren,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, wct,
# Nearest to 'six': seven, eight, five, four,
# Nearest to 'd': b, h, callithrix, UNK,
# Nearest to 'three': five, two, four, seven,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, through, with,
# Nearest to 'all': some, many, several, agouti,
# Nearest to 'from': in, into, under, fingerprints,
# Nearest to 'time': thaler, dasyprocta, fachhochschule, agouti,
#
# Average loss at step  90000 :  4.754712985396385
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, johansson, for, in,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': two, seven, four, five,
# Nearest to 'american': british, including, cebus, french,
# Nearest to 'about': over, that, aren, gollancz,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': gilman, protect, thaler, angkor,
# Nearest to 'six': seven, five, eight, four,
# Nearest to 'd': b, h, callithrix, six,
# Nearest to 'three': five, four, two, seven,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, with, through,
# Nearest to 'all': some, many, several, both,
# Nearest to 'from': into, in, under, fingerprints,
# Nearest to 'time': thaler, dasyprocta, fachhochschule, agouti,
#
# Average loss at step  92000 :  4.707654087066651
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, for, same, thibetanus,
# Nearest to 'more': less, very, most, tadeusz,
# Nearest to 'one': two, four, five, seven,
# Nearest to 'american': british, including, cebus, french,
# Nearest to 'about': that, over, four, gollancz,
# Nearest to 'during': in, after, thaler, on,
# Nearest to 'united': gilman, protect, thaler, angkor,
# Nearest to 'six': seven, five, eight, four,
# Nearest to 'd': b, h, callithrix, UNK,
# Nearest to 'three': four, five, two, six,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, with, around, through,
# Nearest to 'all': some, many, several, both,
# Nearest to 'from': in, into, under, during,
# Nearest to 'time': thaler, fachhochschule, dasyprocta, agouti,
#
# Average loss at step  94000 :  4.616210362017155
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, calypso, thibetanus, johansson,
# Nearest to 'more': less, most, very, tadeusz,
# Nearest to 'one': seven, two, six, five,
# Nearest to 'american': british, including, french, cebus,
# Nearest to 'about': over, that, four, gollancz,
# Nearest to 'during': in, after, thaler, on,
# Nearest to 'united': gilman, protect, thaler, wct,
# Nearest to 'six': seven, eight, five, four,
# Nearest to 'd': b, h, UNK, callithrix,
# Nearest to 'three': five, four, two, seven,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, through, with,
# Nearest to 'all': some, many, several, both,
# Nearest to 'from': in, into, under, fingerprints,
# Nearest to 'time': thaler, fachhochschule, dasyprocta, agouti,
#
# Average loss at step  96000 :  4.724754467487335
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, johansson, in, thibetanus,
# Nearest to 'more': less, most, very, tadeusz,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'american': british, including, french, cebus,
# Nearest to 'about': over, that, aren, thibetanus,
# Nearest to 'during': in, after, thaler, on,
# Nearest to 'united': protect, gilman, thaler, angkor,
# Nearest to 'six': seven, eight, five, four,
# Nearest to 'd': b, six, callithrix, h,
# Nearest to 'three': five, four, seven, two,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, through, with,
# Nearest to 'all': some, many, several, both,
# Nearest to 'from': in, into, under, during,
# Nearest to 'time': thaler, fachhochschule, dasyprocta, thibetanus,
#
# Average loss at step  98000 :  4.61111071062088
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, in, johansson, thibetanus,
# Nearest to 'more': less, most, very, tadeusz,
# Nearest to 'one': wct, agouti, seven, ursus,
# Nearest to 'american': british, including, french, and,
# Nearest to 'about': over, that, thibetanus, gollancz,
# Nearest to 'during': in, thaler, after, on,
# Nearest to 'united': protect, thaler, gilman, wct,
# Nearest to 'six': seven, eight, five, four,
# Nearest to 'd': b, and, callithrix, h,
# Nearest to 'three': five, four, seven, six,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, through, with,
# Nearest to 'all': some, many, several, both,
# Nearest to 'from': in, into, under, of,
# Nearest to 'time': thaler, fachhochschule, dasyprocta, agouti,
#
# Average loss at step  100000 :  4.672690212249756
# Nearest to 'these': some, many, such, several,
# Nearest to 'of': including, johansson, thibetanus, altenberg,
# Nearest to 'more': less, most, very, tadeusz,
# Nearest to 'one': four, two, seven, six,
# Nearest to 'american': british, including, french, and,
# Nearest to 'about': over, that, aren, four,
# Nearest to 'during': in, after, thaler, on,
# Nearest to 'united': protect, thaler, gilman, wct,
# Nearest to 'six': seven, eight, five, four,
# Nearest to 'd': b, callithrix, h, dasyprocta,
# Nearest to 'three': four, five, two, seven,
# Nearest to 'he': it, she, they, who,
# Nearest to 'into': from, around, through, with,
# Nearest to 'all': some, many, several, both,
# Nearest to 'from': in, into, under, during,
# Nearest to 'time': thaler, fachhochschule, dasyprocta, agouti,

# %% [markdown]
# <center><img src="images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings.
# ----
#
# We'll use t-sne.
#
# [t-sne](https://lvdmaaten.github.io/tsne/) is a cool way to visualize of high-dimensional datasets by reducing the number dimensions.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ----
# Reflective Questions
# ----
#
# What do you see?
#
# How would you describe the relationships?

# %% [markdown]
# ------
#
# Let's render and save more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# Embedding Visualizer
# ------
#
# <center><img src="https://2.bp.blogspot.com/-yL_425HS2ck/WEDZLk5cq0I/AAAAAAAABcI/kwy4F4Cmfi4jyG_InIiYu6F7y2-BKTXWQCLcB/s640/embedding-mnist.gif" width="700"/></center>
#
# Check out a better version: [Embedding projector](http://projector.tensorflow.org/)
# - https://www.tensorflow.org/versions/master/how_tos/embedding_viz/index.html

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
